# %%
import numpy as np
from skimage import feature, io

# %%
file = "data/owl.jpg"
img = io.imread(file)
img = img[: ,: ,1]
io.imshow(img)

# %%
edges1 = feature.canny(img)
io.imshow(edges1)

# %%
edges2 = feature.canny(img, sigma=3)
io.imshow(edges2)
